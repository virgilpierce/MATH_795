# %%
n = seq(from = 65, to = 10000, by = 1)
likliehood = 1/n /2^n

# %%
p65 = sum(likliehood)
p65
# Out:
# [1] 8.217267e-22

# %%
pn_given_65 = likliehood / p65

# %%
plot(n[1:20], pn_given_65[1:20])
# Out:
# plot without title

# %%
sum(pn_given_65[1:10])
# Out:
# [1] 0.324996

# %%
pn_given_65[1:2]
# Out:
# [1] 0.03469015 0.03416454
